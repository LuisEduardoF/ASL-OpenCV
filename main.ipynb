# %%
import pandas as pd

df = pd.read_csv("data/asl_dataset.csv", index_col=0)

# %%
from sklearn.model_selection import train_test_split

X = df.drop("class", axis=1)
y = df["class"]

# Split the data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
from models import AlphabetModel

asl = AlphabetModel(X_train, y_train, X_test, y_test)

# %%
epochs, losses = asl.fit()
# Out:
# Epoch [1/100], Loss: 3.0938
# Epoch [2/100], Loss: 2.9860
# Epoch [3/100], Loss: 2.7618
# Epoch [4/100], Loss: 2.8397
# Epoch [5/100], Loss: 2.7271
# Epoch [6/100], Loss: 2.8522
# Epoch [7/100], Loss: 2.7581
# Epoch [8/100], Loss: 2.9643
# Epoch [9/100], Loss: 2.8091
# Epoch [10/100], Loss: 2.7169
# Epoch [11/100], Loss: 2.8110
# Epoch [12/100], Loss: 2.7556
# Epoch [13/100], Loss: 2.7912
# Epoch [14/100], Loss: 2.8532
# Epoch [15/100], Loss: 2.7428
# Epoch [16/100], Loss: 2.7420
# Epoch [17/100], Loss: 2.7647
# Epoch [18/100], Loss: 2.6778
# Epoch [19/100], Loss: 2.7651
# Epoch [20/100], Loss: 2.7035
# Epoch [21/100], Loss: 2.6098
# Epoch [22/100], Loss: 2.7631
# Epoch [23/100], Loss: 2.7646
# Epoch [24/100], Loss: 2.6534
# Epoch [25/100], Loss: 2.7194
# Epoch [26/100], Loss: 2.7422
# Epoch [27/100], Loss: 2.6127
# Epoch [28/100], Loss: 2.6539
# Epoch [29/100], Loss: 2.6316
# Epoch [30/100], Loss: 2.8518
# Epoch [31/100], Loss: 2.7280
# Epoch [32/100], Loss: 2.8069
# Epoch [33/100], Loss: 2.8301
# Epoch [34/100], Loss: 2.6856
# Epoch [35/100], Loss: 2.7740
# Epoch [36/100], Loss: 2.6748
# Epoch [37/100], Loss: 2.6566
# Epoch [38/100], Loss: 2.7805
# Epoch [39/100], Loss: 2.7420
# Epoch [40/100], Loss: 2.8513
# Epoch [41/100], Loss: 2.7235
# Epoch [42/100], Loss: 2.6538
# Epoch [43/100], Loss: 2.6271
# Epoch [44/100], Loss: 2.6749
# Epoch [45/100], Loss: 2.7566
# Epoch [46/100], Loss: 2.7171
# Epoch [47/100], Loss: 2.6535
# Epoch [48/100], Loss: 2.6481
# Epoch [49/100], Loss: 2.5311
# Epoch [50/100], Loss: 2.7007
# Epoch [51/100], Loss: 2.6139
# Epoch [52/100], Loss: 2.6321
# Epoch [53/100], Loss: 2.5552
# Epoch [54/100], Loss: 2.6496
# Epoch [55/100], Loss: 2.5889
# Epoch [56/100], Loss: 2.7840
# Epoch [57/100], Loss: 2.5826
# Epoch [58/100], Loss: 2.5438
# Epoch [59/100], Loss: 2.6345
# Epoch [60/100], Loss: 2.7181
# Epoch [61/100], Loss: 2.6717
# Epoch [62/100], Loss: 2.6775
# Epoch [63/100], Loss: 2.6307
# Epoch [64/100], Loss: 2.5873
# Epoch [65/100], Loss: 2.5631
# Epoch [66/100], Loss: 2.6755
# Epoch [67/100], Loss: 2.4755
# Epoch [68/100], Loss: 2.5862
# Epoch [69/100], Loss: 2.6963
# Epoch [70/100], Loss: 2.6919
# Epoch [71/100], Loss: 2.6065
# Epoch [72/100], Loss: 2.6076
# Epoch [73/100], Loss: 2.6760
# Epoch [74/100], Loss: 2.6080
# Epoch [75/100], Loss: 2.5799
# Epoch [76/100], Loss: 2.6958
# Epoch [77/100], Loss: 2.6099
# Epoch [78/100], Loss: 2.7408
# Epoch [79/100], Loss: 2.7187
# Epoch [80/100], Loss: 2.6675
# Epoch [81/100], Loss: 2.4546
# Epoch [82/100], Loss: 2.4982
# Epoch [83/100], Loss: 2.6766
# Epoch [84/100], Loss: 2.5420
# Epoch [85/100], Loss: 2.6080
# Epoch [86/100], Loss: 2.6740
# Epoch [87/100], Loss: 2.5846
# Epoch [88/100], Loss: 2.5857
# Epoch [89/100], Loss: 2.5652
# Epoch [90/100], Loss: 2.6745
# Epoch [91/100], Loss: 2.6744
# Epoch [92/100], Loss: 2.5622
# Epoch [93/100], Loss: 2.5854
# Epoch [94/100], Loss: 2.6564
# Epoch [95/100], Loss: 2.5644
# Epoch [96/100], Loss: 2.6086
# Epoch [97/100], Loss: 2.7079
# Epoch [98/100], Loss: 2.5426
# Epoch [99/100], Loss: 2.6083
# Epoch [100/100], Loss: 2.4977

# %%
from matplotlib import pyplot as plt
# Sample data
x = epochs # X-axis values (e.g., time or data points)
y = losses  # Y-axis values (e.g., measurements or values)

# Create a line plot
plt.plot(x, y, label='Loss')

# Add labels and a title
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.title('Loss/Epoch Plot')
# Out:
# Text(0.5, 1.0, 'Loss/Epoch Plot')

# %%
asl.score()
# Out:
# Test Accuracy: 72.83%
